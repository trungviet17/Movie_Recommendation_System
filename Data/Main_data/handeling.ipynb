# %%
import pandas as pd

# %%
df = pd.read_csv('main_4.csv')

# %%
tmp1 = df.head(len(df) // 2)
tmp2 = df.tail(len(df)// 2)

# %%
tmp1
# Out:
#      Unnamed: 0.1  Unnamed: 0    Released  \
# 0               0           0  1990-01-12
# 1               1           1  1990-01-12
# 2               2           2  1990-01-12
# 3               3           3  1990-01-12
# 4               4           4  1990-01-19
# ..            ...         ...         ...
# 967           967         967  1996-06-21
# 968           968         968  1996-06-21
# 969           969         969  1996-06-21
# 970           970         970  1996-06-28
# 971           971         971  1996-06-28
#
#                                     English title  TMDB_id  \
# 0                                        Downtown    60778
# 1                                Internal Affairs    11060
# 2    Leatherface: The Texas Chainsaw Massacre III    25018
# 3                                      Ski Patrol    22585
# 4                                  Everybody Wins    41816
# ..                                            ...      ...
# ...

# %%
tmp1.to_csv('main_4.csv')

# %%
tmp2.to_csv('main_11.csv')
